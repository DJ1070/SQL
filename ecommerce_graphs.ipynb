# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import chart_studio.plotly as py
import plotly.graph_objects as go

# %%
df = pd.read_csv('g_customer_sum.csv')

# %%
df2.sort_values('sum_order')
# Out:
#       InvoiceNo          InvoiceDate  CustomerID      Country    sum_order  \
# 0      78547814  2019-03-25 14:19:00     13452.0           DE        13.98
# 1      78556969  2019-06-16 10:11:00     16257.0           DE        22.98
# 2      78561680  2019-07-28 19:13:00     18268.0           DE        23.98
# 3      78542915  2019-02-01 16:18:00     15940.0           DE        31.96
# 4      78569665  2019-10-05 13:34:00     12789.0  Netherlands        35.97
# ...         ...                  ...         ...          ...          ...
# 4333   78569343  2019-10-03 14:34:00     18102.0           DE   7887471.66
# 4334   78553546  2019-05-17 15:42:00     12415.0    Australia   9009114.56
# 4335   78554358  2019-05-24 09:32:00     17450.0           DE   9043451.11
# 4336   78547702  2019-03-24 16:45:00     14911.0      Ireland   9170582.22
# 4337   78557328  2019-06-20 09:53:00     14646.0  Netherlands  21240874.21
#
#       orders  average_order
# 0          2           6.99
# ...

# %%
df = df.drop(df.index[4338])

# %%
fig1 = px.bar(df, x = 'InvoiceNo', y = 'sum_order', color = 'Country')
fig1.update_xaxes(
#     title_text = 'Rides',
     showline = False, showgrid = False
     )
# fig1.update_yaxes(
#     title_text = 'Start Station'
#     )
fig1.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig1.show()

# %%
fig = px.scatter(df, x="InvoiceNo", y="sum_order",
	         size="orders", color="Country",
                 hover_name="Country", size_max=40)
fig.update_xaxes(
     title_text = 'Invoices',
     showline = False, showgrid = False
     )
fig.update_yaxes(
     title_text = 'Turnover per Invoice',
     showline = False, showgrid = False
     )
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig.show()

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'InvoiceDate', 'CustomerID', 'Country', 'sum_order',
#        'orders', 'average_order'],
#       dtype='object')

# %%
fig3 = px.pie(df, values='average_order', names='orders')
fig3.show()
